# %% [markdown]
# <a href="https://colab.research.google.com/github/hongsamhc2/AutoTradingSystem/blob/master/%EC%A1%B0%ED%9B%88%EC%B0%BD/ML_Stock_Data_Split_Train_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/content/drive/My Drive/datasets/stock/DA000020.csv')

# %%
# API 에서 받은 데이터는 최신 날짜 기준으로 정렬 되어 있습니다.
df.head()
# Out:
#        date  time   open   high  ...  deposit  st_turnover  tr_es_ratio  sign
# 0  20201016     0  22750  22950  ...        0          0.0          0.0    53
# 1  20201015     0  23850  23850  ...        0          0.0          0.0    53
# 2  20201014     0  23900  24200  ...        0          0.0          0.0    53
# 3  20201013     0  24200  24550  ...        0          0.0          0.0    50
# 4  20201012     0  24500  24950  ...        0          0.0          0.0    53
#
# [5 rows x 23 columns]

# %%
# 과거 데이터부터 정렬

df.sort_values(by='date',ascending=True,inplace=True)
df.head()
# Out:
#            date  time  open  high  ...  deposit  st_turnover  tr_es_ratio  sign
# 10945  19800104     0  4700  4700  ...        0          0.0          0.0    32
# 10944  19800105     0  4700  4700  ...        0          0.0          0.0    32
# 10943  19800107     0  4990  4990  ...        0          0.0          0.0    32
# 10942  19800108     0  5290  5290  ...        0          0.0          0.0    32
# 10941  19800109     0  5700  5740  ...        0          0.0          0.0    32
#
# [5 rows x 23 columns]

# %%
# 날짜 컬럼 데이터 타입 변경 => datetime

df['date'] = df['date'].astype('str')
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10946 entries, 10945 to 0
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           10946 non-null  datetime64[ns]
#  1   time           10946 non-null  int64
#  2   open           10946 non-null  int64
#  3   high           10946 non-null  int64
#  4   low            10946 non-null  int64
#  5   close          10946 non-null  int64
#  6   prev           10946 non-null  int64
#  7   volume         10946 non-null  int64
#  8   tr_amount      10946 non-null  int64
#  9   sales_qu       10946 non-null  int64
#  10  purchase_qu    10946 non-null  int64
#  11  li_share       10946 non-null  int64
#  12  market_cap     10946 non-null  int64
#  13  fr_cu_holding  10946 non-null  int64
#  14  fr_cu_ratio    10946 non-null  float64
#  15  ad_pr_ratio    10946 non-null  float64
#  16  in_net_buy     10946 non-null  int64
#  17  up_do          10946 non-null  int64
#  18  up_do_ratio    10946 non-null  float64
#  19  deposit        10946 non-null  int64
#  20  st_turnover    10946 non-null  float64
#  21  tr_es_ratio    10946 non-null  float64
#  22  sign           10946 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(17)
# memory usage: 2.0 MB

# %%
# 데이터프레임 index로 날짜 칼럼을 지정

df.set_index(df['date'], inplace=True)
df.head()
# Out:
#                  date  time  open  ...  st_turnover  tr_es_ratio  sign
# date                               ...
# 1980-01-04 1980-01-04     0  4700  ...          0.0          0.0    32
# 1980-01-05 1980-01-05     0  4700  ...          0.0          0.0    32
# 1980-01-07 1980-01-07     0  4990  ...          0.0          0.0    32
# 1980-01-08 1980-01-08     0  5290  ...          0.0          0.0    32
# 1980-01-09 1980-01-09     0  5700  ...          0.0          0.0    32
#
# [5 rows x 23 columns]

# %%
# 최근 100일 데이터

df_len = len(df)
df_100_start = len(df)-100
df_100 = df.iloc[df_100_start:]
df_100
# Out:
#                  date  time   open  ...  st_turnover  tr_es_ratio  sign
# date                                ...
# 2020-05-25 2020-05-25     0  10250  ...          0.0          0.0    50
# 2020-05-26 2020-05-26     0  10400  ...          0.0          0.0    53
# 2020-05-27 2020-05-27     0  10650  ...          0.0          0.0    50
# 2020-05-28 2020-05-28     0  11350  ...          0.0          0.0    53
# 2020-05-29 2020-05-29     0  10900  ...          0.0          0.0    50
# ...               ...   ...    ...  ...          ...          ...   ...
# 2020-10-12 2020-10-12     0  24500  ...          0.0          0.0    53
# 2020-10-13 2020-10-13     0  24200  ...          0.0          0.0    50
# 2020-10-14 2020-10-14     0  23900  ...          0.0          0.0    53
# 2020-10-15 2020-10-15     0  23850  ...          0.0          0.0    53
# 2020-10-16 2020-10-16     0  22750  ...          0.0          0.0    53
#
# [100 rows x 23 columns]

# %%
# 최근 100일 데이터 종가 라인 그래프
df.index.astype('str')
plt.figure(figsize=(16,8))

plt.plot(df.index,df['close'])

# %%
# 최근 100일 봉차트 그리기

# 1. 시가와 종가의 차이 데이터 
df['diff'] = df['close'] - df['open']

# 2. color
df['color'] ='blue'
for i in range(len(df)):
  if df['diff'].iloc[i] >= 0:
    df['color'].iloc[i] = 'red'
  else:
    df['color'].iloc[i] ='blue'
df[['diff','color']].tail()
# 3. 날짜 1일 리스트 만들기
def first_day_list(df):
  date = []
  date.append(df['date'].iloc[0])
  for i in range(len(df)-1):
    date_cu = df['date'].iloc[i]
    date_cu = date_cu.split('-')
    date_ne = df['date'].iloc[i+1]
    date_ne = date_ne.split('-')
    if date_cu[1] != date_ne[1]:
      date.append('-'.join(date_ne))
  if df['date'].iloc[-1] not in date:
    date.append(df['date'].iloc[-1])
  return date

# 4. barchart

df_100 = df.iloc[df_100_start:]
df_100['date'] = df_100['date'].astype('str')
first_day_list = first_day_list(df_100)
plt.figure(figsize=(16,8))
plt.bar(df_100['date'],df_100['diff'],width = 0.5,bottom= df_100['open'],color=df_100['color'])
plt.bar(df_100['date'],df_100['high']-df_100['low'],width=0.1,bottom = df_100['low'],color=df_100['color'])
plt.xticks(first_day_list,rotation = '60')
plt.grid()
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# No handles with labels found to put in legend.

# %%
# label 컬럼 생성 => 다음날 종가 

df['label'] = df['close'].shift(-1)

df[['close','label']]
# Out:
#             close    label
# date
# 1980-01-04   4700   4700.0
# 1980-01-05   4700   4990.0
# 1980-01-07   4990   5290.0
# 1980-01-08   5290   5700.0
# 1980-01-09   5700   5700.0
# ...           ...      ...
# 2020-10-12  24000  24300.0
# 2020-10-13  24300  23850.0
# 2020-10-14  23850  22750.0
# 2020-10-15  22750  21550.0
# 2020-10-16  21550      NaN
#
# [10946 rows x 2 columns]

# %%
# 결측치 값있는 행 삭제

df.dropna(inplace=True)
df.tail()
# Out:
#                  date  time   open   high  ...  sign  diff  color    label
# date                                       ...
# 2020-10-08 2020-10-08     0  23600  24850  ...    50   550    red  24000.0
# 2020-10-12 2020-10-12     0  24500  24950  ...    53  -500   blue  24300.0
# 2020-10-13 2020-10-13     0  24200  24550  ...    50   100    red  23850.0
# 2020-10-14 2020-10-14     0  23900  24200  ...    53   -50   blue  22750.0
# 2020-10-15 2020-10-15     0  23850  23850  ...    53 -1100   blue  21550.0
#
# [5 rows x 26 columns]

# %%
# feature 와 label 데이터셋 생성  / feature 데이터는 종가 
y_label = df['label'].copy()
X_feature = df['close'].copy()

print('y_label Shape : \n' , y_label.shape)
print('X_feature Shape : \n', X_feature.shape)
# Out:
# y_label Shape :
#  (10945,)
# X_feature Shape :
#  (10945,)

# %%
# X_featrue 를 2차원 배열로 변경

X_feature = X_feature.values.reshape(-1,1)

# %%
print(X_feature.shape)
# Out:
# (10945, 1)

# %%
# 훈련 / 테스트 셋으로 분리

from sklearn.model_selection import train_test_split

X_train, X_test , y_train, y_test = train_test_split(X_feature,y_label, train_size = 0.8, shuffle = False)

# %%
# LinearRegression 

from sklearn.linear_model import LinearRegression

lin = LinearRegression()
lin.fit(X_train,y_train)
lin_pred = lin.predict(X_test)
lin_pred
# Out:
# array([ 4562.37944526,  4522.45430542,  4547.40751782, ...,
#        24285.39852702, 23836.2407038 , 22738.29935815])

# %%
# MSE check

from sklearn.metrics import mean_squared_error

# %%
lin_score = mean_squared_error(y_test,lin_pred)
lin_score
# Out:
# 100194.94052964303

# %%
rmse = np.sqrt(lin_score)
rmse
# Out:
# 316.535843988707

# %%
# cross validation

from sklearn.model_selection import cross_val_score

mean_sq = cross_val_score(lin,X_train,y_train,scoring='neg_mean_squared_error',cv=100)
mean_sq
# Out:
# array([-1.10735744e+04, -2.87245643e+03, -2.85844419e+03, -2.23766865e+04,
#        -3.79014118e+03, -7.98064205e+03, -1.90087779e+04, -1.86157796e+03,
#        -3.42764472e+03, -1.58556409e+03, -4.58359310e+04, -5.65505097e+03,
#        -8.17286966e+03, -1.66318674e+04, -8.43257335e+04, -2.56509284e+04,
#        -2.69413629e+04, -2.19221047e+04, -2.04249770e+04, -1.34372237e+04,
#        -3.55708996e+04, -2.00210048e+04, -1.19002313e+04, -1.23281946e+05,
#        -1.39525800e+05, -6.61449622e+04, -9.79986142e+04, -7.51509405e+04,
#        -5.42205543e+04, -6.98724840e+04, -1.41578752e+05, -1.72367313e+05,
#        -6.26784881e+04, -1.38088663e+05, -1.27895031e+05, -1.52596046e+05,
#        -1.17732690e+05, -7.60901656e+04, -8.02059047e+04, -9.34295506e+04,
#        -2.91812050e+05, -2.71578262e+05, -1.95141625e+05, -2.22607125e+05,
#        -1.03411172e+05, -1.61409704e+05, -2.71744823e+05, -1.63682736e+05,
#        -2.42887102e+05, -1.07977665e+06, -4.98651056e+05, -3.99076570e+05,
#        -2.18219359e+05, -3.01028177e+05, -8.97354187e+05, -1.67480034e+06,
#        -1.21695037e+06, -9.30965912e+05, -5.47090236e+05, -1.20877991e+06,
#        -4.23955885e+05, -3.95718784e+05, -3.11450430e+05, -5.38440051e+05,
#        -9.68266553e+05, -4.85908435e+05, -1.62624229e+06, -2.67237884e+05,
#        -1.16736086e+05, -5.50047510e+04, -2.14297191e+05, -8.03500279e+04,
#        -3.99562645e+04, -3.91508698e+04, -5.85357684e+03, -2.79415923e+04,
#        -5.74411583e+04, -2.87600882e+04, -2.35940728e+04, -9.54198889e+03,
#        -9.60242630e+04, -2.79708700e+05, -5.51924142e+05, -2.94684904e+05,
#        -4.30889600e+05, -4.39165676e+05, -3.13474004e+05, -9.27238563e+06,
#        -4.27740464e+06, -2.06146265e+06, -1.93931521e+06, -1.60656639e+06,
#        -1.19553594e+06, -1.85497266e+07, -1.58674834e+04, -1.56105603e+04,
#        -7.24635241e+03, -6.34119399e+03, -1.70111861e+04, -2.33483736e+04])

# %%
rmse = np.sqrt(-mean_sq)
rmse
# Out:
# array([ 105.23105247,   53.59530235,   53.46441983,  149.58839041,
#          61.56412248,   89.33443932,  137.87232461,   43.14600745,
#          58.54609056,   39.81914228,  214.09327635,   75.20007296,
#          90.40392501,  128.96459728,  290.38893484,  160.15907209,
#         164.13824329,  148.06115203,  142.91597886,  115.91903946,
#         188.60249109,  141.49559987,  109.08818141,  351.11528824,
#         373.53152517,  257.18662903,  313.04730346,  274.13671867,
#         232.85307439,  264.33403869,  376.26952075,  415.17142578,
#         250.35672171,  371.60283014,  357.62414725,  390.63543811,
#         343.12197499,  275.84445907,  283.20647013,  305.66247825,
#         540.19630667,  521.1317128 ,  441.74837256,  471.81259485,
#         321.5760757 ,  401.758266  ,  521.2914952 ,  404.57723138,
#         492.83577629, 1039.12301902,  706.15228964,  631.72507497,
#         467.13955006,  548.66034737,  947.28780554, 1294.14077437,
#        1103.15473504,  964.86574814,  739.65548462, 1099.44527199,
#         651.11894868,  629.06182828,  558.07744119,  733.78474444,
#         984.00536235,  697.07132682, 1275.24205035,  516.95056196,
#         341.66662934,  234.53091694,  462.92244577,  283.46080489,
#         199.89063143,  197.86578729,   76.50867166,  167.15738776,
#         239.66885143,  169.58799548,  153.60362245,   97.68310443,
#         309.87781949,  528.87493785,  742.91597251,  542.84887725,
#         656.42181534,  662.69576433,  559.88749213, 3045.05921547,
#        2068.188735  , 1435.77945757, 1392.5929803 , 1267.50399923,
#        1093.40565981, 4306.93935314,  125.96619951,  124.94222771,
#          85.12550974,   79.63161428,  130.42693787,  152.80174593])

# %%
df
# Out:
#                  date  time   open   high  ...  sign  diff  color    label
# date                                       ...
# 1980-01-04 1980-01-04     0   4700   4700  ...    32     0    red   4700.0
# 1980-01-05 1980-01-05     0   4700   4700  ...    32     0    red   4990.0
# 1980-01-07 1980-01-07     0   4990   4990  ...    32     0    red   5290.0
# 1980-01-08 1980-01-08     0   5290   5290  ...    32     0    red   5700.0
# 1980-01-09 1980-01-09     0   5700   5740  ...    32     0    red   5700.0
# ...               ...   ...    ...    ...  ...   ...   ...    ...      ...
# 2020-10-08 2020-10-08     0  23600  24850  ...    50   550    red  24000.0
# 2020-10-12 2020-10-12     0  24500  24950  ...    53  -500   blue  24300.0
# 2020-10-13 2020-10-13     0  24200  24550  ...    50   100    red  23850.0
# 2020-10-14 2020-10-14     0  23900  24200  ...    53   -50   blue  22750.0
# 2020-10-15 2020-10-15     0  23850  23850  ...    53 -1100   blue  21550.0
#
# [10945 rows x 26 columns]

# %%
df_ = df[['close','open','high','low','volume']]

# %%
len(df_.columns)
# Out:
# 5

# %%
def get_subset(df):
  N = len(df.columns)
  result_list = []
  for i in range(1<<N):
    subset_list = []
    for j in range(N):
      if i & (1<<j):
        subset_list.append(j)
    if 0 in subset_list:
     result_list.append(subset_list)
  return result_list

# %%
def train_linear_reg_subset(df):

  columns_index_list = get_subset(df_)
  for i in columns_index_list:
    X_features = df.iloc[:,i]
    X_train, X_test, y_train, y_test = train_test_split(X_features,y_label,shuffle=False, train_size = 0.8)
    lin_reg = LinearRegression()
    lin_scores = cross_val_score(lin_reg,X_train,y_train,scoring='neg_mean_squared_error',cv = 10)
    lin_rmse_scores = np.sqrt(-lin_scores)
    avg_rmse = np.mean(lin_rmse_scores)
    print('Used Columns',df.columns[i])
    print('CV = 10 | negative MSE : ',np.round(lin_scores ,3))
    print('CV = 10 | RMSE : ',np.round(lin_rmse_scores,3))
    print('cv = 10 | SVG : ', np.round(avg_rmse,3))

# %%
train_linear_reg_subset(df_)
# Out:
# Used Columns Index(['close'], dtype='object')
# CV = 10 | negative MSE :  [   -7815.885   -27070.061   -69263.883  -112354.5    -272949.793
#   -810000.961  -527495.71    -52528.397 -1788484.567 -2335876.868]
# CV = 10 | RMSE :  [  88.407  164.53   263.18   335.193  522.446  900.001  726.289  229.191
#  1337.342 1528.358]
# cv = 10 | SVG :  609.494
# Used Columns Index(['close', 'open'], dtype='object')
# CV = 10 | negative MSE :  [   -7923.679   -26611.659   -68036.43   -114641.665  -268857.709
#   -792606.69   -520518.583   -53155.871 -1765739.138 -2348700.327]
# CV = 10 | RMSE :  [  89.015  163.131  260.838  338.588  518.515  890.285  721.47   230.556
#  1328.811 1532.547]
# cv = 10 | SVG :  607.375
# Used Columns Index(['close', 'high'], dtype='object')
# CV = 10 | negative MSE :  [   -7958.835   -27224.561   -69486.144  -114186.513  -270415.206
#   -805396.314  -522658.154   -52444.34  -1787104.11  -2352064.243]
# CV = 10 | RMSE :  [  89.212  164.999  263.602  337.915  520.015  897.439  722.951  229.007
#  1336.826 1533.644]
# cv = 10 | SVG :  609.561
# Used Columns Index(['close', 'open', 'high'], dtype='object')
# CV = 10 | negative MSE :  [   -7853.797   -26522.565   -67737.248  -114232.812  -270127.214
#   -792830.229  -531905.961   -53374.206 -1764825.494 -2348088.78 ]
# CV = 10 | RMSE :  [  88.622  162.857  260.264  337.983  519.738  890.41   729.319  231.029
#  1328.467 1532.347]
# cv = 10 | SVG :  608.104
# Used Columns Index(['close', 'low'], dtype='object')
# CV = 10 | negative MSE :  [   -7907.162   -26694.767   -68167.907  -112909.992  -270752.827
#   -804992.361  -525949.405   -53268.409 -1785981.219 -2332811.843]
# CV = 10 | RMSE :  [  88.922  163.385  261.09   336.021  520.339  897.214  725.224  230.799
#  1336.406 1527.355]
# cv = 10 | SVG :  608.675
# Used Columns Index(['close', 'open', 'low'], dtype='object')
# CV = 10 | negative MSE :  [   -7911.923   -26686.126   -68216.808  -114723.501  -268982.134
#   -792474.114  -520421.859   -53071.875 -1767640.351 -2352998.045]
# CV = 10 | RMSE :  [  88.949  163.359  261.183  338.709  518.635  890.21   721.403  230.373
#  1329.526 1533.949]
# cv = 10 | SVG :  607.63
# Used Columns Index(['close', 'high', 'low'], dtype='object')
# CV = 10 | negative MSE :  [   -8010.693   -26786.425   -68399.733  -113875.817  -269164.448
#   -802147.765  -523446.821   -53056.722 -1785252.281 -2347801.1  ]
# CV = 10 | RMSE :  [  89.502  163.666  261.533  337.455  518.811  895.627  723.496  230.34
#  1336.133 1532.254]
# cv = 10 | SVG :  608.882
# Used Columns Index(['close', 'open', 'high', 'low'], dtype='object')
# CV = 10 | negative MSE :  [   -7809.276   -26648.458   -67956.678  -114157.947  -270821.328
#   -792302.822  -532622.47    -53201.59  -1768007.668 -2351061.807]
# CV = 10 | RMSE :  [  88.37   163.244  260.685  337.873  520.405  890.114  729.81   230.655
#  1329.664 1533.317]
# cv = 10 | SVG :  608.414
# Used Columns Index(['close', 'volume'], dtype='object')
# CV = 10 | negative MSE :  [   -8301.785   -27347.741   -69343.609  -112481.259  -272724.23
#   -810254.909  -528305.758   -52634.072 -1790263.422 -2336774.473]
# CV = 10 | RMSE :  [  91.114  165.372  263.332  335.382  522.23   900.142  726.846  229.421
#  1338.007 1528.651]
# cv = 10 | SVG :  610.05
# Used Columns Index(['close', 'open', 'volume'], dtype='object')
# CV = 10 | negative MSE :  [   -8418.209   -26904.63    -68113.545  -114828.001  -268631.026
#   -792887.862  -521069.635   -53086.661 -1767436.207 -2349430.573]
# CV = 10 | RMSE :  [  91.751  164.026  260.986  338.863  518.296  890.443  721.852  230.405
#  1329.45  1532.785]
# cv = 10 | SVG :  607.886
# Used Columns Index(['close', 'high', 'volume'], dtype='object')
# CV = 10 | negative MSE :  [   -8228.232   -27413.929   -69552.75   -114198.459  -270521.738
#   -806432.707  -524218.529   -52389.656 -1788126.547 -2351711.168]
# CV = 10 | RMSE :  [  90.71   165.572  263.729  337.933  520.117  898.016  724.029  228.888
#  1337.208 1533.529]
# cv = 10 | SVG :  609.973
# Used Columns Index(['close', 'open', 'high', 'volume'], dtype='object')
# CV = 10 | negative MSE :  [   -8559.141   -26808.824   -67584.801  -114142.383  -270414.014
#   -793881.185  -528915.497   -53718.095 -1763879.595 -2346779.323]
# CV = 10 | RMSE :  [  92.516  163.734  259.971  337.85   520.013  891.     727.266  231.772
#  1328.111 1531.92 ]
# cv = 10 | SVG :  608.415
# Used Columns Index(['close', 'low', 'volume'], dtype='object')
# CV = 10 | negative MSE :  [   -8789.41    -26985.954   -68008.681  -113010.72   -270071.388
#   -804556.384  -523835.688   -53679.025 -1789952.106 -2333900.692]
# CV = 10 | RMSE :  [  93.752  164.274  260.785  336.171  519.684  896.971  723.765  231.687
#  1337.891 1527.711]
# cv = 10 | SVG :  609.269
# Used Columns Index(['close', 'open', 'low', 'volume'], dtype='object')
# CV = 10 | negative MSE :  [   -8408.434   -26919.35    -68187.153  -114855.267  -268692.056
#   -793190.98   -521418.788   -53078.532 -1773445.463 -2352488.465]
# CV = 10 | RMSE :  [  91.698  164.071  261.127  338.903  518.355  890.613  722.093  230.388
#  1331.708 1533.782]
# cv = 10 | SVG :  608.274
# Used Columns Index(['close', 'high', 'low', 'volume'], dtype='object')
# CV = 10 | negative MSE :  [   -8674.169   -27044.815   -68272.276  -113790.257  -269119.008
#   -803163.358  -522320.028   -53256.181 -1788624.275 -2346214.55 ]
# CV = 10 | RMSE :  [  93.135  164.453  261.29   337.328  518.767  896.194  722.717  230.773
#  1337.395 1531.736]
# cv = 10 | SVG :  609.379
# Used Columns Index(['close', 'open', 'high', 'low', 'volume'], dtype='object')
# CV = 10 | negative MSE :  [   -8466.655   -26881.958   -67759.482  -114103.328  -270913.931
#   -793613.984  -530713.724   -53560.745 -1770184.48  -2349335.362]
# CV = 10 | RMSE :  [  92.014  163.957  260.307  337.792  520.494  890.85   728.501  231.432
#  1330.483 1532.754]
# cv = 10 | SVG :  608.858
