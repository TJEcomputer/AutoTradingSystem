# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
#!pip install FinanceDataReader

# %%
import FinanceDataReader as fdr

# %%
df_dongaPH = fdr.DataReader('000020', '2000')
print(df_dongaPH)
df_dongaPH.to_csv('dongaPH.csv')
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2000-01-04   2663   3116   2663   3116  169430  0.149815
# 2000-01-05   3172   3578   2946   3305  728760  0.060655
# 2000-01-06   3304   3474   2813   2871  260640 -0.131316
# 2000-01-07   2983   3294   2831   3296  453080  0.148032
# 2000-01-10   3644   3700   3162   3211  752880 -0.025789
# ...           ...    ...    ...    ...     ...       ...
# 2020-10-12  24500  24950  22950  24000  540131 -0.006211
# 2020-10-13  24200  24550  23900  24300  426678  0.012500
# 2020-10-14  23900  24200  23600  23850  420287 -0.018519
# 2020-10-15  23850  23850  22450  22750  508031 -0.046122
# 2020-10-16  22750  22950  20750  21400  854449 -0.059341
#
# [5121 rows x 6 columns]

# %%
drop_columns = ['Change']
df_dongaPH.drop(drop_columns, axis = 1, inplace =True)

# %%
df_dongaPH.head()
# Out:
#             Open  High   Low  Close  Volume
# Date
# 2000-01-04  2663  3116  2663   3116  169430
# 2000-01-05  3172  3578  2946   3305  728760
# 2000-01-06  3304  3474  2813   2871  260640
# 2000-01-07  2983  3294  2831   3296  453080
# 2000-01-10  3644  3700  3162   3211  752880

# %%
df_dongaPH.isnull().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
plt.figure(figsize = (24,16))
plt.title('Close price history')
plt.plot(df_dongaPH['Close'])
plt.xlabel('Date')
plt.ylabel('Close')
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
y_train_data = df_dongaPH['Close']
X_train_data = df_dongaPH.drop(['Close'], axis=1, inplace=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_data,y_train_data, random_state=1)

# %%
import talib as ta
