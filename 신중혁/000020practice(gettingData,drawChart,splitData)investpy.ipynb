# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
import investpy

# %%
df = df = investpy.get_stock_historical_data(stock='000020',
                                        country='South Korea',
                                        from_date='04/01/2000',
                                        to_date='10/10/2020',
                                        as_json=False,
                                        order='ascending')

# %%
df.head(50)
# Out:
#               Open    High     Low   Close  Volume Currency
# Date
# 2011-08-23  4855.0  4990.0  4855.0  4935.0  127354      KRW
# 2011-08-24  5020.0  5020.0  4820.0  4840.0  185301      KRW
# 2011-08-25  4925.0  5020.0  4850.0  4950.0  121430      KRW
# 2011-08-26  4970.0  5190.0  4760.0  5070.0  222830      KRW
# 2011-08-29  5090.0  5380.0  5020.0  5200.0  231782      KRW
# 2011-08-30  5280.0  5340.0  5180.0  5280.0  137751      KRW
# 2011-08-31  5320.0  5320.0  5100.0  5170.0  144338      KRW
# 2011-09-01  5210.0  5330.0  5110.0  5210.0  207861      KRW
# 2011-09-02  5210.0  5220.0  5090.0  5170.0  145140      KRW
# 2011-09-05  5100.0  5170.0  5000.0  5050.0  177951      KRW
# 2011-09-06  5000.0  5010.0  4860.0  4915.0  224650      KRW
# 2011-09-07  4970.0  5180.0  4960.0  5180.0  114060      KRW
# 2011-09-08  5180.0  5200.0  4990.0  5060.0  124264      KRW
# 2011-09-09  5100.0  5100.0  5000.0  5020.0   31287      KRW
# 2011-09-14  5020.0  5050.0  4770.0  4775.0   95219      KRW
# ...

# %%
df.isnull().sum()
# Out:
# Open        0
# High        0
# Low         0
# Close       0
# Volume      0
# Currency    0
# dtype: int64

# %%
drop_columns = ['Currency','Volume']
df.drop(drop_columns, axis = 1, inplace =True)

# %%
df.tail(50)
# Out:
#                Open     High      Low    Close
# Date
# 2020-08-07  29250.0  29800.0  28450.0  29350.0
# 2020-08-09  29350.0  29350.0  29350.0  29350.0
# 2020-08-10  29650.0  31250.0  29200.0  30300.0
# 2020-08-11  30300.0  34300.0  23900.0  24400.0
# 2020-08-12  25400.0  26700.0  24250.0  24950.0
# 2020-08-13  24800.0  25100.0  21800.0  22550.0
# 2020-08-14  22400.0  22400.0  20700.0  21200.0
# 2020-08-17  21200.0  21200.0  21200.0  21200.0
# 2020-08-18  21450.0  24850.0  21400.0  22000.0
# 2020-08-19  22750.0  23850.0  22250.0  22900.0
# 2020-08-20  23600.0  24150.0  22500.0  22850.0
# 2020-08-21  23000.0  23200.0  21500.0  21650.0
# 2020-08-23  21650.0  21650.0  21650.0  21650.0
# 2020-08-24  21800.0  24000.0  21100.0  23100.0
# 2020-08-25  22950.0  23500.0  22800.0  23250.0
# 2020-08-26  23300.0  24150.0  23000.0  23750.0
# 2020-08-27  23850.0  24650.0  23350.0  23750.0
# 2020-08-28  23750.0  23900.0  23000.0  23050.0
# 2020-08-30  23050.0  23050.0  23050.0  23050.0
# ...

# %%
plt.figure(figsize = (24,16))
plt.title('Close price history')
plt.plot(df['Close'])
plt.xlabel('Date')
plt.ylabel('Close')
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
y_train_data = df['Close']
X_train_data = df.drop(['Close'], axis=1, inplace=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_data,y_train_data, random_state=1)
